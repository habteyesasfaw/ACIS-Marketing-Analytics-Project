# %% [markdown]
# # A/B Hypothesis Testing Analysis

# %% [markdown]
# ## 1. Setup
# Import necessary libraries and load data.

# %%
# Import necessary libraries

import pandas as pd
import sys
import os

# %%
# Adjust the path to point to the 'scripts' directory
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../scripts')))
from ab_testing_analysis import  load_data, clean_data, segment_data, perform_t_test, report_results

# %% [markdown]
# # Load data

# %%
file_path = '../../data/MachineLearningRating_v3.txt'
# Replace delimiter with the correct one
df = pd.read_csv(file_path, delimiter='|')  # Change delimiter as needed

# Display the first few rows of the dataframe
df.head()
# Out:
# C:\Users\habteyes.asfaw\AppData\Local\Temp\ipykernel_3016\502432007.py:3: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter='|')  # Change delimiter as needed
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %% [markdown]
# # Clean the dataset

# %%
df_clean = clean_data(df)
df_clean.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %% [markdown]
# # 2. Select Metrics
# Select the key performance indicators (KPIs) for analysis.

# %%
kpi_column = 'TotalClaims'

# %% [markdown]
# ## 3. Data Segmentation
# Create groups for comparison: Control Group (Group A) and Test Group (Group B).

# %%
feature_column = 'Province'
control_value = 'ProvinceA'
test_value = 'ProvinceB'

# %% [markdown]
# ## 4. Statistical Testing
# ### 4.1 Risk Differences Across Provinces

# %%
# 1. Testing risk differences across provinces
print("\n1. Testing risk differences across provinces:")
province_control = 'ProvinceA'  # Replace with actual province name
province_test = 'ProvinceB'     # Replace with actual province name
result_province = ab_testing(
    df=df,
    feature='Province',
    control_value=province_control,
    test_value=province_test,
    kpi_col=kpi_col,
    test_type='t-test'  # Assuming TotalClaims is numerical
)
print(result_province)
# Out:
# 1. Testing risk differences across provinces:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       3 province_control = 'ProvinceA'  # Replace with actual province name
#       4 province_test = 'ProvinceB'     # Replace with actual province name
#       5 result_province = ab_testing(
# ----> 6     df=df,
#       7     feature='Province',
#       8     control_value=province_control,
#       9     test_value=province_test,
#      10     kpi_col=kpi_col,
#      11     test_type='t-test'  # Assuming TotalClaims is numerical
#      12 )
#      13 print(result_province)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 4.2 Risk Differences Between Zip Codes

# %%
print("\nTesting for Risk Differences Between Zip Codes:")
def test_risk_differences_between_zip_codes(df):
    zip_codes = df['PostalCode'].unique()
    results = {}
    
    for i in range(len(zip_codes)):
        for j in range(i + 1, len(zip_codes)):
            zip_a = zip_codes[i]
            zip_b = zip_codes[j]
            group_a, group_b = segment_data(df, 'PostalCode', zip_a, zip_b)
            p_value = perform_t_test(group_a[kpi_risk], group_b[kpi_risk])
            results[f'{zip_a} vs {zip_b}'] = analyze_results(p_value)
    
    return results

# %% [markdown]
# ### 4.3 Margin Differences Between Zip Codes

# %%
# Margin differences between zip codes
t_stat, p_value = perform_t_test(group_a, group_b, 'ProfitMargin')
print(f'Test Statistic: {t_stat}, p-value: {p_value}')
print(analyze_results(p_value))

# %% [markdown]
# ### 4.4 Risk Differences Between Women and Men

# %%
# Risk differences between genders
chi2_stat, p_value = perform_chi_squared_test(group_a, group_b, 'Gender')
print(f'Chi2 Statistic: {chi2_stat}, p-value: {p_value}')
print(analyze_results(p_value))

# %% [markdown]
# ## 5. Analyze and Report
# Summarize findings and interpret results.

# %%
# Summarize findings
findings = {
    'risk_provinces': analyze_results(p_value),
    'risk_zip_codes': analyze_results(p_value),
    'margin_zip_codes': analyze_results(p_value),
    'risk_gender': analyze_results(p_value)
}

print("Findings:")
for test, result in findings.items():
    print(f"{test}: {result}")
