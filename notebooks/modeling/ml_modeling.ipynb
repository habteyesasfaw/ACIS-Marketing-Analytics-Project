# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import sys
import os
import numpy as np

# %% [markdown]
# ## Adjust the path to point to the 'scripts' directory

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../scripts')))
from model_training import (data_cleaning,data_preparation, split_data, linear_regression_model, random_forest_model, xgboost_model, evaluate_model, feature_importance_shap
)

# %% [markdown]
# # Load data

# %%
file_path = '../../data/MachineLearningRating_v3.txt'
# Replace delimiter with the correct one
data = pd.read_csv(file_path, delimiter='|')  # Change delimiter as needed

# Display the first few rows of the dataframe
data.head()
# Out:
# C:\Users\habteyes.asfaw\AppData\Local\Temp\ipykernel_18948\607214028.py:3: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, delimiter='|')  # Change delimiter as needed
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
cleaned_data = data_cleaning(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cleaned_data = data_cleaning(data)
#
# File c:\Users\habteyes.asfaw\10Accadamy\ACIS-Marketing-Analytics-Project\scripts\model_training.py:28, in data_cleaning(data)
#      25 data = data.dropna(thresh=threshold, axis=1)
#      27 # Fill missing numerical values with the column median
# ---> 28 num_cols = data.select_dtypes(include=[np.number]).columns
#      29 data[num_cols] = data[num_cols].fillna(data[num_cols].median())
#      31 # Fill missing categorical values with the mode (most frequent)
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Step 1: Data Preparation

# %%
prepared_data = data_preparation(data)
