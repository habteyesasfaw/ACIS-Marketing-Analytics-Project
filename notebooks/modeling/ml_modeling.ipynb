# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import sys
import os
import numpy as np

# %% [markdown]
# ## Adjust the path to point to the 'scripts' directory

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../scripts')))
from model_training import (data_cleaning,data_preparation,feature_engineering,encode_categorical_data, split_data, train_linear_regression, random_forest_model, xgboost_model, evaluate_model, feature_importance_shap
)

# %% [markdown]
# # Load data

# %%
file_path = '../../data/MachineLearningRating_v3.txt'
# Replace delimiter with the correct one
data = pd.read_csv(file_path, delimiter='|')  # Change delimiter as needed

# Display the first few rows of the dataframe
data.head()
# Out:
# C:\Users\habteyes.asfaw\AppData\Local\Temp\ipykernel_6920\607214028.py:3: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, delimiter='|')  # Change delimiter as needed
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
# Basic statistical details
data.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
data.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %% [markdown]
# # Step 1: Data Preparation

# %% [markdown]
# ###  Handle missing data

# %%
cleaned_data = data_cleaning(data)
# Out:
# c:\Users\habteyes.asfaw\10Accadamy\ACIS-Marketing-Analytics-Project\scripts\model_training.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[num_cols] = data[num_cols].fillna(data[num_cols].median())
# c:\Users\habteyes.asfaw\10Accadamy\ACIS-Marketing-Analytics-Project\scripts\model_training.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].fillna(data[col].mode()[0])

# %% [markdown]
# ### Feature Engineering:

# %%
engineered_data = feature_engineering(cleaned_data)

# %% [markdown]
# ### Encoding Categorical Data

# %%
# List of categorical columns to encode
categorical_columns = ['TransactionMonth', 'Citizenship', 'LegalType', 'Title', 'Language', 'Bank', 'AccountType',
                       'MaritalStatus', 'Gender', 'Country', 'Province', 'MainCrestaZone', 'SubCrestaZone', 'ItemType',
                       'VehicleType', 'make', 'Model', 'bodytype', 'VehicleIntroDate', 'AlarmImmobiliser',
                       'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'TermFrequency', 'ExcessSelected',
                       'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType']

# Encode categorical data
encoded_data = encode_categorical_data(engineered_data, categorical_columns, encode_type='one-hot')

# %% [markdown]
# ### Train-Test Split

# %%
# Specify target column (Update this to an actual column name)
target_column = 'TotalPremium'  # or 'TotalClaims' based on what you want to predict

# Split data into training and testing sets
X_train, X_test, y_train, y_test = split_data(encoded_data, target_column, test_size=0.3)

# %% [markdown]
# # Step 3: Build Models
# ## Linear Regression

# %%
# Train and evaluate Linear Regression model
lr_model, lr_mse, lr_r2 = train_linear_regression(X_train, y_train, X_test, y_test)

print(f"Linear Regression Model MSE: {lr_mse}")
print(f"Linear Regression Model R2 Score: {lr_r2}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Train and evaluate Linear Regression model
# ----> 2 lr_model, lr_mse, lr_r2 = train_linear_regression(X_train, y_train, X_test, y_test)
#       4 print(f"Linear Regression Model MSE: {lr_mse}")
#       5 print(f"Linear Regression Model R2 Score: {lr_r2}")
#
# File c:\Users\habteyes.asfaw\10Accadamy\ACIS-Marketing-Analytics-Project\scripts\model_training.py:96, in train_linear_regression(X_train, y_train, X_test, y_test)
#      94 def train_linear_regression(X_train, y_train, X_test, y_test):
#      95     model = LinearRegression()
# ---> 96     model.fit(X_train, y_train)
#      97     y_pred = model.predict(X_test)
#      99     mse = mean_squared_error(y_test, y_pred)
#
# ...
